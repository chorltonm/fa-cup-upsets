# %%
# Import Libaries

import requests
import math
import json
import os
import pandas as pd

from google.cloud import bigquery
from google.oauth2 import service_account
from google.colab import drive

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Change default ouput directory
os.chdir('/content/drive/MyDrive/birkbeck_msc-project/output_files')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Authentication credentials and keys

# SportDevs API Authentication & Headers
bearer_token = "svdt5OEplUqf9ZCrMJpqHQ"

headers = {
    "Accept": "application/json",
    "Authorization": f"Bearer {bearer_token}"
}

# Google Service Account

# Load the JSON key from local Google Collab file
key = json.load(open('/content/drive/MyDrive/service_account.json', 'r'))

# Authenticate using the loaded key
credentials = service_account.Credentials.from_service_account_info(key)

# Set up the BigQuery client with the credentials to project
client = bigquery.Client(credentials=credentials, project='birkbeck-msc-project-422917')

# %%
# Set filter variables
country = 'England'
league_name = 'League One'

# Get League ID
leagues_endpoint = f"https://football.sportdevs.com/leagues?class_name=eq.{country}&name=eq.{league_name}"
leagues_response = requests.get(leagues_endpoint, headers=headers)
leagues_data = leagues_response.json()

print(leagues_data)

# Get Seasons Data for League One and save seasons data to extract file
from_date = '2008-07-01'

seasons_list = []

with open(f"{league_name}_seasons_data.json", 'w') as seasons_file:
  for league in leagues_data:
      league_id = league['id']

      # Get seasons for the league
      seasons_url = f"https://football.sportdevs.com/seasons?league_id=eq.{league_id}&start_time=gte.{from_date}"
      seasons_response = requests.get(seasons_url, headers=headers)
      seasons_data = seasons_response.json()

      matches_list = []
      lineups_list = []
      season_standings_list = []

      for season in seasons_data:
          seasons_file.write(f"{json.dumps(season)}\n")
          seasons_list.append(season)
          season_id = season['id']

          #season_teams_url = f"https://football.sportdevs.com/teams-by-season?season_id=eq.{season_id}"
          season_standings_url = f"https://football.sportdevs.com/standings?type=eq.total&season_id=eq.{season_id}"
          season_standings_response = requests.get(season_standings_url, headers=headers)
          season_standings_data = season_standings_response.json()

          for season in season_standings_data:
              season_standings_list.append(season)

              print(*season_standings_list, sep="\n")
              # Get all matches for season ID and maximum 50 results per request as per api documentation
              limit = 50
              offset = 0
              number_of_matches = 0

              while True:
                  matches_url = f"https://football.sportdevs.com/matches?season_id=eq.{season_id}&limit={limit}&offset={offset}"
                  matches_response = requests.get(matches_url, headers=headers)
                  matches_data = matches_response.json()

                  for matches in matches_data:
                      matches_list.append(matches)

                      if 'lineups_id' in matches:
                          lineups_list.append(matches['lineups_id'])

                  offset += limit
                  number_of_matches += len(matches_data)
                  print(number_of_matches)

                  if len(matches_data) < limit:
                      break

# Write all season teams from list to file at once
with open(f"{league_name}_season_standings_data.json", 'w') as season_standings_file:
  for season in season_standings_list:
      season_standings_file.write(f"{json.dumps(season)}\n")

# Write all matches from list to file at once
with open(f"{league_name}_matches_data.json", 'w') as matches_file:
  for match in matches_list:
      matches_file.write(f"{json.dumps(match)}\n")

lineup_ids = sorted(lineups_list)
total_seasons = len(seasons_list)
total_matches = len(matches_list)
total_lineup_ids = len(lineup_ids)
print(f"Total seasons: {total_seasons}")
print(f"Total mactches: {total_matches}")
print(f"Total line up ids: {total_lineup_ids}")

#print(*matches_list, sep="\n")
# Out:
# [{'id': 166, 'name': 'League One', 'importance': 0, 'level': 3, 'current_champion_team_id': 154, 'current_champion_team_name': 'Wigan Athletic', 'current_champion_team_hash_image': '013da198947194a758f25a84ef131a2e6e89e1a69d60352da04b5626964eb805', 'current_champion_team_num_titles': 3, 'teams_most_titles': [{'team_id': 154, 'team_name': 'Wigan Athletic', 'team_hash_image': '013da198947194a758f25a84ef131a2e6e89e1a69d60352da04b5626964eb805'}], 'most_titles': 3, 'primary_color': '#20429a', 'secondary_color': '#848888', 'higher_leagues': [{'league_id': 172, 'league_name': 'Championship', 'league_hash_image': 'f6e1e146682aca6bc217db36a4e0a4cff4a74e5df43a43353140c3fe647bf730'}], 'lower_leagues': [{'league_id': 162, 'league_name': 'League Two', 'league_hash_image': 'd5485dd777a6fcc0bd4a9ca479e0edf806cee624f193868f53dbcbffedd0bc16'}], 'start_league': '2023-08-04T00:00:00+00:00', 'end_league': '2024-05-18T00:00:00+00:00', 'hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'class_id': 158, 'class_name': 'England', 'class_hash_image': '39bcba0feb303912d90fe5917cdfbabab8d0ac780d3c73f387344293b2e3ae58'}]
# {'id': 1128, 'tournament_id': 70, 'type': 'total', 'name': 'League One', 'season_id': 2875, 'season_name': 'League One 12/13', 'league_id': 166, 'league_name': 'League One', 'league_hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'competitors': [{'wins': 9, 'draws': 14, 'losses': 23, 'points': 41, 'matches': 46, 'team_id': 4401, 'position': 23, 'team_name': 'Hartlepool United', 'scores_for': 39, 'scores_against': 67, 'team_hash_image': '316897ddb25ccc206a9996ea7de1a7624ec72bbe4f9da152a54c52f3a4cb5a00'}, {'wins': 9, 'draws': 14, 'losses': 23, 'points': 41, 'matches': 46, 'team_id': 8515, 'position': 22, 'team_name': 'Bury AFC', 'scores_for': 45, 'scores_against': 73, 'team_hash_image': '71a647a3b2aba958f5357aa23c32d1540aa9f844996acffcbfbbdd7e9a647b79'}, {'wins': 10, 'draws': 12, 'losses': 24, 'points': 32, 'matches': 46, 'team_id': 4296, 'position': 24, 'team_name': 'Portsmouth', 'scores_for': 51, 'scores_against': 69, 'team_hash_image': 'd1e01014a47db9d9d8bc12dfa02886979294e37b81e81bcf1fe2b35b674eb69d'}, {'wins': 13, 'draws': 9, 'losses': 24, 'points': 48, 'matches': 46, 'team_id': 4564, 'position': 21, 'team_name': 'Scunthorpe United', 'scores_for': 49, 'scores_against': 73, 'team_hash_image': 'e4ec0e6d57e34566dfb7f879a73f9ddef12f6be8da41f14077da50e4e389217c'}, {'wins': 13, 'draws': 16, 'losses': 17, 'points': 55, 'matches': 46, 'team_id': 7117, 'position': 16, 'team_name': 'Shrewsbury Town', 'scores_for': 54, 'scores_against': 60, 'team_hash_image': '08924cb4f356ee51e6c50f9796e2a6c4182fbcd0d0ef7cedcd927bc371b3dd72'}, {'wins': 14, 'draws': 9, 'losses': 23, 'points': 51, 'matches': 46, 'team_id': 7991, 'position': 20, 'team_name': 'Colchester United', 'scores_for': 47, 'scores_against': 68, 'team_hash_image': '7bbb33a7a87aed13cd4edc16a7141a3c60e4e8e3d6bf7e7a1d4ee235779c3347'}, {'wins': 14, 'draws': 9, 'losses': 23, 'points': 51, 'matches': 46, 'team_id': 8020, 'position': 19, 'team_name': 'Oldham Athletic', 'scores_for': 46, 'scores_against': 59, 'team_hash_image': '77d19813ea1cd72114970e1407517cdb5b9e6839a590563c56fcd73e801f4ccb'}, {'wins': 14, 'draws': 13, 'losses': 19, 'points': 55, 'matches': 46, 'team_id': 4325, 'position': 17, 'team_name': 'Carlisle United', 'scores_for': 56, 'scores_against': 77, 'team_hash_image': '04e2714fdeba28c3ca4e4e24454b82b19d0714652d474e5374f043846c19a160'}, {'wins': 14, 'draws': 17, 'losses': 15, 'points': 59, 'matches': 46, 'team_id': 8411, 'position': 14, 'team_name': 'Preston North End', 'scores_for': 54, 'scores_against': 49, 'team_hash_image': 'b9bc7368e3fbf3b5477f85ed028d5a6204592e40d8f68b4b6072995f741117ef'}, {'wins': 15, 'draws': 9, 'losses': 22, 'points': 54, 'matches': 46, 'team_id': 4298, 'position': 18, 'team_name': 'Stevenage', 'scores_for': 47, 'scores_against': 64, 'team_hash_image': 'e9f1fa960b8ff5769a0edc433be1e4c1dcd2d1c5c2a251f0bdf0a72ce7386e33'}, {'wins': 16, 'draws': 17, 'losses': 13, 'points': 65, 'matches': 46, 'team_id': 4041, 'position': 12, 'team_name': 'Notts County', 'scores_for': 61, 'scores_against': 49, 'team_hash_image': '24548edf86064af8e8c29afcfb4469ee5948c0b6ba9634683e3ae629ef067eba'}, {'wins': 17, 'draws': 17, 'losses': 12, 'points': 68, 'matches': 46, 'team_id': 4581, 'position': 9, 'team_name': 'Walsall', 'scores_for': 65, 'scores_against': 58, 'team_hash_image': '7b2d4e565f525cf48ea8f4c719d7af05ea1f96fa6aff5497056daa3d644d08a0'}, {'wins': 18, 'draws': 10, 'losses': 18, 'points': 64, 'matches': 46, 'team_id': 4534, 'position': 13, 'team_name': 'Crewe Alexandra', 'scores_for': 54, 'scores_against': 62, 'team_hash_image': 'ff8f313b6e8a7def03299289670e41461ad7a8a9ce2f9dda11e2d685a4f4b26a'}, {'wins': 18, 'draws': 11, 'losses': 17, 'points': 55, 'matches': 46, 'team_id': 4538, 'position': 15, 'team_name': 'Coventry City', 'scores_for': 66, 'scores_against': 59, 'team_hash_image': 'c58b7625cde7b4cb651d8b983b87516943368ab96564c39c329be338e098c171'}, {'wins': 18, 'draws': 14, 'losses': 14, 'points': 68, 'matches': 46, 'team_id': 787 ...
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 590
# {'id': 1128, 'tournament_id': 70, 'type': 'total', 'name': 'League One', 'season_id': 2875, 'season_name': 'League One 12/13', 'league_id': 166, 'league_name': 'League One', 'league_hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'competitors': [{'wins': 9, 'draws': 14, 'losses': 23, 'points': 41, 'matches': 46, 'team_id': 4401, 'position': 23, 'team_name': 'Hartlepool United', 'scores_for': 39, 'scores_against': 67, 'team_hash_image': '316897ddb25ccc206a9996ea7de1a7624ec72bbe4f9da152a54c52f3a4cb5a00'}, {'wins': 9, 'draws': 14, 'losses': 23, 'points': 41, 'matches': 46, 'team_id': 8515, 'position': 22, 'team_name': 'Bury AFC', 'scores_for': 45, 'scores_against': 73, 'team_hash_image': '71a647a3b2aba958f5357aa23c32d1540aa9f844996acffcbfbbdd7e9a647b79'}, {'wins': 10, 'draws': 12, 'losses': 24, 'points': 32, 'matches': 46, 'team_id': 4296, 'position': 24, 'team_name': 'Portsmouth', 'scores_for': 51, 'scores_against': 69, 'team_hash_image': 'd1e01014a47db9d9d8bc12dfa02886979294e37b81e81bcf1fe2b35b674eb69d'}, {'wins': 13, 'draws': 9, 'losses': 24, 'points': 48, 'matches': 46, 'team_id': 4564, 'position': 21, 'team_name': 'Scunthorpe United', 'scores_for': 49, 'scores_against': 73, 'team_hash_image': 'e4ec0e6d57e34566dfb7f879a73f9ddef12f6be8da41f14077da50e4e389217c'}, {'wins': 13, 'draws': 16, 'losses': 17, 'points': 55, 'matches': 46, 'team_id': 7117, 'position': 16, 'team_name': 'Shrewsbury Town', 'scores_for': 54, 'scores_against': 60, 'team_hash_image': '08924cb4f356ee51e6c50f9796e2a6c4182fbcd0d0ef7cedcd927bc371b3dd72'}, {'wins': 14, 'draws': 9, 'losses': 23, 'points': 51, 'matches': 46, 'team_id': 7991, 'position': 20, 'team_name': 'Colchester United', 'scores_for': 47, 'scores_against': 68, 'team_hash_image': '7bbb33a7a87aed13cd4edc16a7141a3c60e4e8e3d6bf7e7a1d4ee235779c3347'}, {'wins': 14, 'draws': 9, 'losses': 23, 'points': 51, 'matches': 46, 'team_id': 8020, 'position': 19, 'team_name': 'Oldham Athletic', 'scores_for': 46, 'scores_against': 59, 'team_hash_image': '77d19813ea1cd72114970e1407517cdb5b9e6839a590563c56fcd73e801f4ccb'}, {'wins': 14, 'draws': 13, 'losses': 19, 'points': 55, 'matches': 46, 'team_id': 4325, 'position': 17, 'team_name': 'Carlisle United', 'scores_for': 56, 'scores_against': 77, 'team_hash_image': '04e2714fdeba28c3ca4e4e24454b82b19d0714652d474e5374f043846c19a160'}, {'wins': 14, 'draws': 17, 'losses': 15, 'points': 59, 'matches': 46, 'team_id': 8411, 'position': 14, 'team_name': 'Preston North End', 'scores_for': 54, 'scores_against': 49, 'team_hash_image': 'b9bc7368e3fbf3b5477f85ed028d5a6204592e40d8f68b4b6072995f741117ef'}, {'wins': 15, 'draws': 9, 'losses': 22, 'points': 54, 'matches': 46, 'team_id': 4298, 'position': 18, 'team_name': 'Stevenage', 'scores_for': 47, 'scores_against': 64, 'team_hash_image': 'e9f1fa960b8ff5769a0edc433be1e4c1dcd2d1c5c2a251f0bdf0a72ce7386e33'}, {'wins': 16, 'draws': 17, 'losses': 13, 'points': 65, 'matches': 46, 'team_id': 4041, 'position': 12, 'team_name': 'Notts County', 'scores_for': 61, 'scores_against': 49, 'team_hash_image': '24548edf86064af8e8c29afcfb4469ee5948c0b6ba9634683e3ae629ef067eba'}, {'wins': 17, 'draws': 17, 'losses': 12, 'points': 68, 'matches': 46, 'team_id': 4581, 'position': 9, 'team_name': 'Walsall', 'scores_for': 65, 'scores_against': 58, 'team_hash_image': '7b2d4e565f525cf48ea8f4c719d7af05ea1f96fa6aff5497056daa3d644d08a0'}, {'wins': 18, 'draws': 10, 'losses': 18, 'points': 64, 'matches': 46, 'team_id': 4534, 'position': 13, 'team_name': 'Crewe Alexandra', 'scores_for': 54, 'scores_against': 62, 'team_hash_image': 'ff8f313b6e8a7def03299289670e41461ad7a8a9ce2f9dda11e2d685a4f4b26a'}, {'wins': 18, 'draws': 11, 'losses': 17, 'points': 55, 'matches': 46, 'team_id': 4538, 'position': 15, 'team_name': 'Coventry City', 'scores_for': 66, 'scores_against': 59, 'team_hash_image': 'c58b7625cde7b4cb651d8b983b87516943368ab96564c39c329be338e098c171'}, {'wins': 18, 'draws': 14, 'losses': 14, 'points': 68, 'matches': 46, 'team_id': 787 ...
# {'id': 13131, 'tournament_id': 70, 'type': 'total', 'name': 'League One', 'season_id': 2918, 'season_name': 'League One 11/12', 'league_id': 166, 'league_name': 'League One', 'league_hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'competitors': [{'wins': 8, 'draws': 14, 'losses': 24, 'points': 38, 'matches': 46, 'team_id': 4370, 'position': 24, 'team_name': 'Rochdale', 'scores_for': 47, 'scores_against': 81, 'team_hash_image': '96f0f08dba8ca5c46830dd7f612c4ba586ef036b67a13686e981dc2ac443a397'}, {'wins': 10, 'draws': 12, 'losses': 24, 'points': 42, 'matches': 46, 'team_id': 195, 'position': 22, 'team_name': 'Chesterfield', 'scores_for': 56, 'scores_against': 81, 'team_hash_image': '1773c3612bb87681dde2d10edf64e3d18d86a246f92dfd9044f4be904be0f56f'}, {'wins': 10, 'draws': 12, 'losses': 24, 'points': 42, 'matches': 46, 'team_id': 4478, 'position': 23, 'team_name': 'Exeter City', 'scores_for': 46, 'scores_against': 75, 'team_hash_image': 'd354cd9c3b70770d13964e926e4cf7268cd423cdf71026967529e11351408210'}, {'wins': 10, 'draws': 20, 'losses': 16, 'points': 50, 'matches': 46, 'team_id': 4581, 'position': 19, 'team_name': 'Walsall', 'scores_for': 51, 'scores_against': 57, 'team_hash_image': '7b2d4e565f525cf48ea8f4c719d7af05ea1f96fa6aff5497056daa3d644d08a0'}, {'wins': 10, 'draws': 22, 'losses': 14, 'points': 52, 'matches': 46, 'team_id': 4564, 'position': 18, 'team_name': 'Scunthorpe United', 'scores_for': 55, 'scores_against': 59, 'team_hash_image': 'e4ec0e6d57e34566dfb7f879a73f9ddef12f6be8da41f14077da50e4e389217c'}, {'wins': 11, 'draws': 10, 'losses': 25, 'points': 43, 'matches': 46, 'team_id': 4559, 'position': 21, 'team_name': 'Wycombe Wanderers', 'scores_for': 65, 'scores_against': 88, 'team_hash_image': 'b95a035bf0e7860f20d604aa8784550a1550e556211a1374179025bf6dc3c50a'}, {'wins': 13, 'draws': 11, 'losses': 22, 'points': 50, 'matches': 46, 'team_id': 4256, 'position': 20, 'team_name': 'Leyton Orient', 'scores_for': 48, 'scores_against': 75, 'team_hash_image': '02c60245ad65c53763986dbf71c2f32c9e13acbd7018a6775c284939e0697c4c'}, {'wins': 13, 'draws': 15, 'losses': 18, 'points': 54, 'matches': 46, 'team_id': 8411, 'position': 15, 'team_name': 'Preston North End', 'scores_for': 54, 'scores_against': 68, 'team_hash_image': 'b9bc7368e3fbf3b5477f85ed028d5a6204592e40d8f68b4b6072995f741117ef'}, {'wins': 13, 'draws': 20, 'losses': 13, 'points': 59, 'matches': 46, 'team_id': 7991, 'position': 10, 'team_name': 'Colchester United', 'scores_for': 61, 'scores_against': 66, 'team_hash_image': '7bbb33a7a87aed13cd4edc16a7141a3c60e4e8e3d6bf7e7a1d4ee235779c3347'}, {'wins': 14, 'draws': 12, 'losses': 20, 'points': 54, 'matches': 46, 'team_id': 4065, 'position': 17, 'team_name': 'Yeovil Town', 'scores_for': 59, 'scores_against': 80, 'team_hash_image': 'c9c1976e517fc74b065f524ef84ad68b5bb2d6f3257772df9f5d3bb0f306d509'}, {'wins': 14, 'draws': 12, 'losses': 20, 'points': 54, 'matches': 46, 'team_id': 8020, 'position': 16, 'team_name': 'Oldham Athletic', 'scores_for': 50, 'scores_against': 66, 'team_hash_image': '77d19813ea1cd72114970e1407517cdb5b9e6839a590563c56fcd73e801f4ccb'}, {'wins': 14, 'draws': 14, 'losses': 18, 'points': 56, 'matches': 46, 'team_id': 4401, 'position': 13, 'team_name': 'Hartlepool United', 'scores_for': 50, 'scores_against': 55, 'team_hash_image': '316897ddb25ccc206a9996ea7de1a7624ec72bbe4f9da152a54c52f3a4cb5a00'}, {'wins': 14, 'draws': 14, 'losses': 18, 'points': 56, 'matches': 46, 'team_id': 4460, 'position': 12, 'team_name': 'Tranmere Rovers', 'scores_for': 49, 'scores_against': 53, 'team_hash_image': 'd49a32711871cd446193dde2b4bf5e1a1a43d3a862525deb9495c3d022cff86a'}, {'wins': 15, 'draws': 11, 'losses': 20, 'points': 56, 'matches': 46, 'team_id': 8515, 'position': 14, 'team_name': 'Bury AFC', 'scores_for': 60, 'scores_against': 79, 'team_hash_image': '71a647a3b2aba958f5357aa23c32d1540aa9f844996acffcbfbbdd7e9a647b79'}, {'wins': 15, 'draws': 13, 'losses': 18, 'points': 58, 'matches': 46, 'team_id': ...
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 579
# {'id': 1128, 'tournament_id': 70, 'type': 'total', 'name': 'League One', 'season_id': 2875, 'season_name': 'League One 12/13', 'league_id': 166, 'league_name': 'League One', 'league_hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'competitors': [{'wins': 9, 'draws': 14, 'losses': 23, 'points': 41, 'matches': 46, 'team_id': 4401, 'position': 23, 'team_name': 'Hartlepool United', 'scores_for': 39, 'scores_against': 67, 'team_hash_image': '316897ddb25ccc206a9996ea7de1a7624ec72bbe4f9da152a54c52f3a4cb5a00'}, {'wins': 9, 'draws': 14, 'losses': 23, 'points': 41, 'matches': 46, 'team_id': 8515, 'position': 22, 'team_name': 'Bury AFC', 'scores_for': 45, 'scores_against': 73, 'team_hash_image': '71a647a3b2aba958f5357aa23c32d1540aa9f844996acffcbfbbdd7e9a647b79'}, {'wins': 10, 'draws': 12, 'losses': 24, 'points': 32, 'matches': 46, 'team_id': 4296, 'position': 24, 'team_name': 'Portsmouth', 'scores_for': 51, 'scores_against': 69, 'team_hash_image': 'd1e01014a47db9d9d8bc12dfa02886979294e37b81e81bcf1fe2b35b674eb69d'}, {'wins': 13, 'draws': 9, 'losses': 24, 'points': 48, 'matches': 46, 'team_id': 4564, 'position': 21, 'team_name': 'Scunthorpe United', 'scores_for': 49, 'scores_against': 73, 'team_hash_image': 'e4ec0e6d57e34566dfb7f879a73f9ddef12f6be8da41f14077da50e4e389217c'}, {'wins': 13, 'draws': 16, 'losses': 17, 'points': 55, 'matches': 46, 'team_id': 7117, 'position': 16, 'team_name': 'Shrewsbury Town', 'scores_for': 54, 'scores_against': 60, 'team_hash_image': '08924cb4f356ee51e6c50f9796e2a6c4182fbcd0d0ef7cedcd927bc371b3dd72'}, {'wins': 14, 'draws': 9, 'losses': 23, 'points': 51, 'matches': 46, 'team_id': 7991, 'position': 20, 'team_name': 'Colchester United', 'scores_for': 47, 'scores_against': 68, 'team_hash_image': '7bbb33a7a87aed13cd4edc16a7141a3c60e4e8e3d6bf7e7a1d4ee235779c3347'}, {'wins': 14, 'draws': 9, 'losses': 23, 'points': 51, 'matches': 46, 'team_id': 8020, 'position': 19, 'team_name': 'Oldham Athletic', 'scores_for': 46, 'scores_against': 59, 'team_hash_image': '77d19813ea1cd72114970e1407517cdb5b9e6839a590563c56fcd73e801f4ccb'}, {'wins': 14, 'draws': 13, 'losses': 19, 'points': 55, 'matches': 46, 'team_id': 4325, 'position': 17, 'team_name': 'Carlisle United', 'scores_for': 56, 'scores_against': 77, 'team_hash_image': '04e2714fdeba28c3ca4e4e24454b82b19d0714652d474e5374f043846c19a160'}, {'wins': 14, 'draws': 17, 'losses': 15, 'points': 59, 'matches': 46, 'team_id': 8411, 'position': 14, 'team_name': 'Preston North End', 'scores_for': 54, 'scores_against': 49, 'team_hash_image': 'b9bc7368e3fbf3b5477f85ed028d5a6204592e40d8f68b4b6072995f741117ef'}, {'wins': 15, 'draws': 9, 'losses': 22, 'points': 54, 'matches': 46, 'team_id': 4298, 'position': 18, 'team_name': 'Stevenage', 'scores_for': 47, 'scores_against': 64, 'team_hash_image': 'e9f1fa960b8ff5769a0edc433be1e4c1dcd2d1c5c2a251f0bdf0a72ce7386e33'}, {'wins': 16, 'draws': 17, 'losses': 13, 'points': 65, 'matches': 46, 'team_id': 4041, 'position': 12, 'team_name': 'Notts County', 'scores_for': 61, 'scores_against': 49, 'team_hash_image': '24548edf86064af8e8c29afcfb4469ee5948c0b6ba9634683e3ae629ef067eba'}, {'wins': 17, 'draws': 17, 'losses': 12, 'points': 68, 'matches': 46, 'team_id': 4581, 'position': 9, 'team_name': 'Walsall', 'scores_for': 65, 'scores_against': 58, 'team_hash_image': '7b2d4e565f525cf48ea8f4c719d7af05ea1f96fa6aff5497056daa3d644d08a0'}, {'wins': 18, 'draws': 10, 'losses': 18, 'points': 64, 'matches': 46, 'team_id': 4534, 'position': 13, 'team_name': 'Crewe Alexandra', 'scores_for': 54, 'scores_against': 62, 'team_hash_image': 'ff8f313b6e8a7def03299289670e41461ad7a8a9ce2f9dda11e2d685a4f4b26a'}, {'wins': 18, 'draws': 11, 'losses': 17, 'points': 55, 'matches': 46, 'team_id': 4538, 'position': 15, 'team_name': 'Coventry City', 'scores_for': 66, 'scores_against': 59, 'team_hash_image': 'c58b7625cde7b4cb651d8b983b87516943368ab96564c39c329be338e098c171'}, {'wins': 18, 'draws': 14, 'losses': 14, 'points': 68, 'matches': 46, 'team_id': 787 ...
# {'id': 13131, 'tournament_id': 70, 'type': 'total', 'name': 'League One', 'season_id': 2918, 'season_name': 'League One 11/12', 'league_id': 166, 'league_name': 'League One', 'league_hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'competitors': [{'wins': 8, 'draws': 14, 'losses': 24, 'points': 38, 'matches': 46, 'team_id': 4370, 'position': 24, 'team_name': 'Rochdale', 'scores_for': 47, 'scores_against': 81, 'team_hash_image': '96f0f08dba8ca5c46830dd7f612c4ba586ef036b67a13686e981dc2ac443a397'}, {'wins': 10, 'draws': 12, 'losses': 24, 'points': 42, 'matches': 46, 'team_id': 195, 'position': 22, 'team_name': 'Chesterfield', 'scores_for': 56, 'scores_against': 81, 'team_hash_image': '1773c3612bb87681dde2d10edf64e3d18d86a246f92dfd9044f4be904be0f56f'}, {'wins': 10, 'draws': 12, 'losses': 24, 'points': 42, 'matches': 46, 'team_id': 4478, 'position': 23, 'team_name': 'Exeter City', 'scores_for': 46, 'scores_against': 75, 'team_hash_image': 'd354cd9c3b70770d13964e926e4cf7268cd423cdf71026967529e11351408210'}, {'wins': 10, 'draws': 20, 'losses': 16, 'points': 50, 'matches': 46, 'team_id': 4581, 'position': 19, 'team_name': 'Walsall', 'scores_for': 51, 'scores_against': 57, 'team_hash_image': '7b2d4e565f525cf48ea8f4c719d7af05ea1f96fa6aff5497056daa3d644d08a0'}, {'wins': 10, 'draws': 22, 'losses': 14, 'points': 52, 'matches': 46, 'team_id': 4564, 'position': 18, 'team_name': 'Scunthorpe United', 'scores_for': 55, 'scores_against': 59, 'team_hash_image': 'e4ec0e6d57e34566dfb7f879a73f9ddef12f6be8da41f14077da50e4e389217c'}, {'wins': 11, 'draws': 10, 'losses': 25, 'points': 43, 'matches': 46, 'team_id': 4559, 'position': 21, 'team_name': 'Wycombe Wanderers', 'scores_for': 65, 'scores_against': 88, 'team_hash_image': 'b95a035bf0e7860f20d604aa8784550a1550e556211a1374179025bf6dc3c50a'}, {'wins': 13, 'draws': 11, 'losses': 22, 'points': 50, 'matches': 46, 'team_id': 4256, 'position': 20, 'team_name': 'Leyton Orient', 'scores_for': 48, 'scores_against': 75, 'team_hash_image': '02c60245ad65c53763986dbf71c2f32c9e13acbd7018a6775c284939e0697c4c'}, {'wins': 13, 'draws': 15, 'losses': 18, 'points': 54, 'matches': 46, 'team_id': 8411, 'position': 15, 'team_name': 'Preston North End', 'scores_for': 54, 'scores_against': 68, 'team_hash_image': 'b9bc7368e3fbf3b5477f85ed028d5a6204592e40d8f68b4b6072995f741117ef'}, {'wins': 13, 'draws': 20, 'losses': 13, 'points': 59, 'matches': 46, 'team_id': 7991, 'position': 10, 'team_name': 'Colchester United', 'scores_for': 61, 'scores_against': 66, 'team_hash_image': '7bbb33a7a87aed13cd4edc16a7141a3c60e4e8e3d6bf7e7a1d4ee235779c3347'}, {'wins': 14, 'draws': 12, 'losses': 20, 'points': 54, 'matches': 46, 'team_id': 4065, 'position': 17, 'team_name': 'Yeovil Town', 'scores_for': 59, 'scores_against': 80, 'team_hash_image': 'c9c1976e517fc74b065f524ef84ad68b5bb2d6f3257772df9f5d3bb0f306d509'}, {'wins': 14, 'draws': 12, 'losses': 20, 'points': 54, 'matches': 46, 'team_id': 8020, 'position': 16, 'team_name': 'Oldham Athletic', 'scores_for': 50, 'scores_against': 66, 'team_hash_image': '77d19813ea1cd72114970e1407517cdb5b9e6839a590563c56fcd73e801f4ccb'}, {'wins': 14, 'draws': 14, 'losses': 18, 'points': 56, 'matches': 46, 'team_id': 4401, 'position': 13, 'team_name': 'Hartlepool United', 'scores_for': 50, 'scores_against': 55, 'team_hash_image': '316897ddb25ccc206a9996ea7de1a7624ec72bbe4f9da152a54c52f3a4cb5a00'}, {'wins': 14, 'draws': 14, 'losses': 18, 'points': 56, 'matches': 46, 'team_id': 4460, 'position': 12, 'team_name': 'Tranmere Rovers', 'scores_for': 49, 'scores_against': 53, 'team_hash_image': 'd49a32711871cd446193dde2b4bf5e1a1a43d3a862525deb9495c3d022cff86a'}, {'wins': 15, 'draws': 11, 'losses': 20, 'points': 56, 'matches': 46, 'team_id': 8515, 'position': 14, 'team_name': 'Bury AFC', 'scores_for': 60, 'scores_against': 79, 'team_hash_image': '71a647a3b2aba958f5357aa23c32d1540aa9f844996acffcbfbbdd7e9a647b79'}, {'wins': 15, 'draws': 13, 'losses': 18, 'points': 58, 'matches': 46, 'team_id': ...
# {'id': 15392, 'tournament_id': 70, 'type': 'total', 'name': 'League One', 'season_id': 1790, 'season_name': 'League One 21/22', 'league_id': 166, 'league_name': 'League One', 'league_hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'competitors': [{'wins': 6, 'draws': 19, 'losses': 21, 'points': 37, 'matches': 46, 'team_id': 8107, 'position': 23, 'team_name': 'AFC Wimbledon', 'scores_for': 49, 'scores_against': 75, 'team_hash_image': 'dcff6df928b63ac1779cf83354fb4c6f0dcfbb64c97b63ee0ed2e02ac09ecdf2'}, {'wins': 7, 'draws': 8, 'losses': 31, 'points': 29, 'matches': 46, 'team_id': 4534, 'position': 24, 'team_name': 'Crewe Alexandra', 'scores_for': 37, 'scores_against': 83, 'team_hash_image': 'ff8f313b6e8a7def03299289670e41461ad7a8a9ce2f9dda11e2d685a4f4b26a'}, {'wins': 8, 'draws': 16, 'losses': 22, 'points': 40, 'matches': 46, 'team_id': 7518, 'position': 20, 'team_name': 'Fleetwood Town', 'scores_for': 62, 'scores_against': 82, 'team_hash_image': '48f74a3d52341d622a41d796658133182360d10ebdefc093f6268ea5ae65a02c'}, {'wins': 8, 'draws': 16, 'losses': 22, 'points': 40, 'matches': 46, 'team_id': 7896, 'position': 21, 'team_name': 'Gillingham', 'scores_for': 35, 'scores_against': 69, 'team_hash_image': '7cd94cdf477938774593b8581a87cf2ac2a9c61176cdc5ea034569ec6e8cfb29'}, {'wins': 10, 'draws': 8, 'losses': 28, 'points': 38, 'matches': 46, 'team_id': 7996, 'position': 22, 'team_name': 'Doncaster Rovers', 'scores_for': 37, 'scores_against': 82, 'team_hash_image': '403e17b026d8db7a8d1ecc3663750c5816cb4a920fa2a452f6059498800b7d90'}, {'wins': 10, 'draws': 12, 'losses': 24, 'points': 42, 'matches': 46, 'team_id': 7799, 'position': 19, 'team_name': 'Morecambe', 'scores_for': 57, 'scores_against': 88, 'team_hash_image': 'b9ac5fc7cc1571246c264fbc5ca39c4b28fe1de2aa9093bd68248d3d0969f02c'}, {'wins': 12, 'draws': 14, 'losses': 20, 'points': 50, 'matches': 46, 'team_id': 7117, 'position': 18, 'team_name': 'Shrewsbury Town', 'scores_for': 47, 'scores_against': 51, 'team_hash_image': '08924cb4f356ee51e6c50f9796e2a6c4182fbcd0d0ef7cedcd927bc371b3dd72'}, {'wins': 13, 'draws': 17, 'losses': 16, 'points': 56, 'matches': 46, 'team_id': 7812, 'position': 15, 'team_name': 'Cheltenham Town', 'scores_for': 66, 'scores_against': 80, 'team_hash_image': '19c659e7c9f3a162af51d6212735f4e03f4db96a2202a9fa06cf9d3aceed78dc'}, {'wins': 14, 'draws': 10, 'losses': 22, 'points': 52, 'matches': 46, 'team_id': 7543, 'position': 17, 'team_name': 'Lincoln City', 'scores_for': 55, 'scores_against': 63, 'team_hash_image': '63b905f3235067ef7446ed93573927fdd4046d58fb2893119e4be376791c462b'}, {'wins': 14, 'draws': 11, 'losses': 21, 'points': 53, 'matches': 46, 'team_id': 7225, 'position': 16, 'team_name': 'Burton Albion', 'scores_for': 51, 'scores_against': 67, 'team_hash_image': 'c7c46048703aace97a6c53fa194d9543f7581ec7af49c0fe375561750076e68d'}, {'wins': 15, 'draws': 13, 'losses': 18, 'points': 58, 'matches': 46, 'team_id': 7385, 'position': 14, 'team_name': 'Cambridge United', 'scores_for': 56, 'scores_against': 74, 'team_hash_image': 'db018f2b74d4244cb117b1a72c07cfb8d73e3677d7bd2a2da0c8b787da98fe0b'}, {'wins': 17, 'draws': 8, 'losses': 21, 'points': 59, 'matches': 46, 'team_id': 4511, 'position': 13, 'team_name': 'Charlton Athletic', 'scores_for': 55, 'scores_against': 59, 'team_hash_image': '323dbb6366850550d0e7a0cbeb4e51c31bb88ed596bb006bea4de2e15fae6e04'}, {'wins': 17, 'draws': 10, 'losses': 19, 'points': 61, 'matches': 46, 'team_id': 7989, 'position': 12, 'team_name': 'Accrington Stanley', 'scores_for': 61, 'scores_against': 80, 'team_hash_image': 'b1c92a4342ab17f8b72b02b7e981a4ca88d52b651e9465a51cfb365ede934f99'}, {'wins': 18, 'draws': 16, 'losses': 12, 'points': 70, 'matches': 46, 'team_id': 4364, 'position': 11, 'team_name': 'Ipswich Town', 'scores_for': 67, 'scores_against': 46, 'team_hash_image': 'e8a89aac97ce210544749edf3e268b36a27d68d5bcc2c8104bfd0587e60f345d'}, {'wins': 20, 'draws': 13, 'losses': 13, 'points': 73, 'matches': 46, 'team ...
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 613
# {'id': 1128, 'tournament_id': 70, 'type': 'total', 'name': 'League One', 'season_id': 2875, 'season_name': 'League One 12/13', 'league_id': 166, 'league_name': 'League One', 'league_hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'competitors': [{'wins': 9, 'draws': 14, 'losses': 23, 'points': 41, 'matches': 46, 'team_id': 4401, 'position': 23, 'team_name': 'Hartlepool United', 'scores_for': 39, 'scores_against': 67, 'team_hash_image': '316897ddb25ccc206a9996ea7de1a7624ec72bbe4f9da152a54c52f3a4cb5a00'}, {'wins': 9, 'draws': 14, 'losses': 23, 'points': 41, 'matches': 46, 'team_id': 8515, 'position': 22, 'team_name': 'Bury AFC', 'scores_for': 45, 'scores_against': 73, 'team_hash_image': '71a647a3b2aba958f5357aa23c32d1540aa9f844996acffcbfbbdd7e9a647b79'}, {'wins': 10, 'draws': 12, 'losses': 24, 'points': 32, 'matches': 46, 'team_id': 4296, 'position': 24, 'team_name': 'Portsmouth', 'scores_for': 51, 'scores_against': 69, 'team_hash_image': 'd1e01014a47db9d9d8bc12dfa02886979294e37b81e81bcf1fe2b35b674eb69d'}, {'wins': 13, 'draws': 9, 'losses': 24, 'points': 48, 'matches': 46, 'team_id': 4564, 'position': 21, 'team_name': 'Scunthorpe United', 'scores_for': 49, 'scores_against': 73, 'team_hash_image': 'e4ec0e6d57e34566dfb7f879a73f9ddef12f6be8da41f14077da50e4e389217c'}, {'wins': 13, 'draws': 16, 'losses': 17, 'points': 55, 'matches': 46, 'team_id': 7117, 'position': 16, 'team_name': 'Shrewsbury Town', 'scores_for': 54, 'scores_against': 60, 'team_hash_image': '08924cb4f356ee51e6c50f9796e2a6c4182fbcd0d0ef7cedcd927bc371b3dd72'}, {'wins': 14, 'draws': 9, 'losses': 23, 'points': 51, 'matches': 46, 'team_id': 7991, 'position': 20, 'team_name': 'Colchester United', 'scores_for': 47, 'scores_against': 68, 'team_hash_image': '7bbb33a7a87aed13cd4edc16a7141a3c60e4e8e3d6bf7e7a1d4ee235779c3347'}, {'wins': 14, 'draws': 9, 'losses': 23, 'points': 51, 'matches': 46, 'team_id': 8020, 'position': 19, 'team_name': 'Oldham Athletic', 'scores_for': 46, 'scores_against': 59, 'team_hash_image': '77d19813ea1cd72114970e1407517cdb5b9e6839a590563c56fcd73e801f4ccb'}, {'wins': 14, 'draws': 13, 'losses': 19, 'points': 55, 'matches': 46, 'team_id': 4325, 'position': 17, 'team_name': 'Carlisle United', 'scores_for': 56, 'scores_against': 77, 'team_hash_image': '04e2714fdeba28c3ca4e4e24454b82b19d0714652d474e5374f043846c19a160'}, {'wins': 14, 'draws': 17, 'losses': 15, 'points': 59, 'matches': 46, 'team_id': 8411, 'position': 14, 'team_name': 'Preston North End', 'scores_for': 54, 'scores_against': 49, 'team_hash_image': 'b9bc7368e3fbf3b5477f85ed028d5a6204592e40d8f68b4b6072995f741117ef'}, {'wins': 15, 'draws': 9, 'losses': 22, 'points': 54, 'matches': 46, 'team_id': 4298, 'position': 18, 'team_name': 'Stevenage', 'scores_for': 47, 'scores_against': 64, 'team_hash_image': 'e9f1fa960b8ff5769a0edc433be1e4c1dcd2d1c5c2a251f0bdf0a72ce7386e33'}, {'wins': 16, 'draws': 17, 'losses': 13, 'points': 65, 'matches': 46, 'team_id': 4041, 'position': 12, 'team_name': 'Notts County', 'scores_for': 61, 'scores_against': 49, 'team_hash_image': '24548edf86064af8e8c29afcfb4469ee5948c0b6ba9634683e3ae629ef067eba'}, {'wins': 17, 'draws': 17, 'losses': 12, 'points': 68, 'matches': 46, 'team_id': 4581, 'position': 9, 'team_name': 'Walsall', 'scores_for': 65, 'scores_against': 58, 'team_hash_image': '7b2d4e565f525cf48ea8f4c719d7af05ea1f96fa6aff5497056daa3d644d08a0'}, {'wins': 18, 'draws': 10, 'losses': 18, 'points': 64, 'matches': 46, 'team_id': 4534, 'position': 13, 'team_name': 'Crewe Alexandra', 'scores_for': 54, 'scores_against': 62, 'team_hash_image': 'ff8f313b6e8a7def03299289670e41461ad7a8a9ce2f9dda11e2d685a4f4b26a'}, {'wins': 18, 'draws': 11, 'losses': 17, 'points': 55, 'matches': 46, 'team_id': 4538, 'position': 15, 'team_name': 'Coventry City', 'scores_for': 66, 'scores_against': 59, 'team_hash_image': 'c58b7625cde7b4cb651d8b983b87516943368ab96564c39c329be338e098c171'}, {'wins': 18, 'draws': 14, 'losses': 14, 'points': 68, 'matches': 46, 'team_id': 787 ...
# {'id': 13131, 'tournament_id': 70, 'type': 'total', 'name': 'League One', 'season_id': 2918, 'season_name': 'League One 11/12', 'league_id': 166, 'league_name': 'League One', 'league_hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'competitors': [{'wins': 8, 'draws': 14, 'losses': 24, 'points': 38, 'matches': 46, 'team_id': 4370, 'position': 24, 'team_name': 'Rochdale', 'scores_for': 47, 'scores_against': 81, 'team_hash_image': '96f0f08dba8ca5c46830dd7f612c4ba586ef036b67a13686e981dc2ac443a397'}, {'wins': 10, 'draws': 12, 'losses': 24, 'points': 42, 'matches': 46, 'team_id': 195, 'position': 22, 'team_name': 'Chesterfield', 'scores_for': 56, 'scores_against': 81, 'team_hash_image': '1773c3612bb87681dde2d10edf64e3d18d86a246f92dfd9044f4be904be0f56f'}, {'wins': 10, 'draws': 12, 'losses': 24, 'points': 42, 'matches': 46, 'team_id': 4478, 'position': 23, 'team_name': 'Exeter City', 'scores_for': 46, 'scores_against': 75, 'team_hash_image': 'd354cd9c3b70770d13964e926e4cf7268cd423cdf71026967529e11351408210'}, {'wins': 10, 'draws': 20, 'losses': 16, 'points': 50, 'matches': 46, 'team_id': 4581, 'position': 19, 'team_name': 'Walsall', 'scores_for': 51, 'scores_against': 57, 'team_hash_image': '7b2d4e565f525cf48ea8f4c719d7af05ea1f96fa6aff5497056daa3d644d08a0'}, {'wins': 10, 'draws': 22, 'losses': 14, 'points': 52, 'matches': 46, 'team_id': 4564, 'position': 18, 'team_name': 'Scunthorpe United', 'scores_for': 55, 'scores_against': 59, 'team_hash_image': 'e4ec0e6d57e34566dfb7f879a73f9ddef12f6be8da41f14077da50e4e389217c'}, {'wins': 11, 'draws': 10, 'losses': 25, 'points': 43, 'matches': 46, 'team_id': 4559, 'position': 21, 'team_name': 'Wycombe Wanderers', 'scores_for': 65, 'scores_against': 88, 'team_hash_image': 'b95a035bf0e7860f20d604aa8784550a1550e556211a1374179025bf6dc3c50a'}, {'wins': 13, 'draws': 11, 'losses': 22, 'points': 50, 'matches': 46, 'team_id': 4256, 'position': 20, 'team_name': 'Leyton Orient', 'scores_for': 48, 'scores_against': 75, 'team_hash_image': '02c60245ad65c53763986dbf71c2f32c9e13acbd7018a6775c284939e0697c4c'}, {'wins': 13, 'draws': 15, 'losses': 18, 'points': 54, 'matches': 46, 'team_id': 8411, 'position': 15, 'team_name': 'Preston North End', 'scores_for': 54, 'scores_against': 68, 'team_hash_image': 'b9bc7368e3fbf3b5477f85ed028d5a6204592e40d8f68b4b6072995f741117ef'}, {'wins': 13, 'draws': 20, 'losses': 13, 'points': 59, 'matches': 46, 'team_id': 7991, 'position': 10, 'team_name': 'Colchester United', 'scores_for': 61, 'scores_against': 66, 'team_hash_image': '7bbb33a7a87aed13cd4edc16a7141a3c60e4e8e3d6bf7e7a1d4ee235779c3347'}, {'wins': 14, 'draws': 12, 'losses': 20, 'points': 54, 'matches': 46, 'team_id': 4065, 'position': 17, 'team_name': 'Yeovil Town', 'scores_for': 59, 'scores_against': 80, 'team_hash_image': 'c9c1976e517fc74b065f524ef84ad68b5bb2d6f3257772df9f5d3bb0f306d509'}, {'wins': 14, 'draws': 12, 'losses': 20, 'points': 54, 'matches': 46, 'team_id': 8020, 'position': 16, 'team_name': 'Oldham Athletic', 'scores_for': 50, 'scores_against': 66, 'team_hash_image': '77d19813ea1cd72114970e1407517cdb5b9e6839a590563c56fcd73e801f4ccb'}, {'wins': 14, 'draws': 14, 'losses': 18, 'points': 56, 'matches': 46, 'team_id': 4401, 'position': 13, 'team_name': 'Hartlepool United', 'scores_for': 50, 'scores_against': 55, 'team_hash_image': '316897ddb25ccc206a9996ea7de1a7624ec72bbe4f9da152a54c52f3a4cb5a00'}, {'wins': 14, 'draws': 14, 'losses': 18, 'points': 56, 'matches': 46, 'team_id': 4460, 'position': 12, 'team_name': 'Tranmere Rovers', 'scores_for': 49, 'scores_against': 53, 'team_hash_image': 'd49a32711871cd446193dde2b4bf5e1a1a43d3a862525deb9495c3d022cff86a'}, {'wins': 15, 'draws': 11, 'losses': 20, 'points': 56, 'matches': 46, 'team_id': 8515, 'position': 14, 'team_name': 'Bury AFC', 'scores_for': 60, 'scores_against': 79, 'team_hash_image': '71a647a3b2aba958f5357aa23c32d1540aa9f844996acffcbfbbdd7e9a647b79'}, {'wins': 15, 'draws': 13, 'losses': 18, 'points': 58, 'matches': 46, 'team_id': ...
# {'id': 15392, 'tournament_id': 70, 'type': 'total', 'name': 'League One', 'season_id': 1790, 'season_name': 'League One 21/22', 'league_id': 166, 'league_name': 'League One', 'league_hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'competitors': [{'wins': 6, 'draws': 19, 'losses': 21, 'points': 37, 'matches': 46, 'team_id': 8107, 'position': 23, 'team_name': 'AFC Wimbledon', 'scores_for': 49, 'scores_against': 75, 'team_hash_image': 'dcff6df928b63ac1779cf83354fb4c6f0dcfbb64c97b63ee0ed2e02ac09ecdf2'}, {'wins': 7, 'draws': 8, 'losses': 31, 'points': 29, 'matches': 46, 'team_id': 4534, 'position': 24, 'team_name': 'Crewe Alexandra', 'scores_for': 37, 'scores_against': 83, 'team_hash_image': 'ff8f313b6e8a7def03299289670e41461ad7a8a9ce2f9dda11e2d685a4f4b26a'}, {'wins': 8, 'draws': 16, 'losses': 22, 'points': 40, 'matches': 46, 'team_id': 7518, 'position': 20, 'team_name': 'Fleetwood Town', 'scores_for': 62, 'scores_against': 82, 'team_hash_image': '48f74a3d52341d622a41d796658133182360d10ebdefc093f6268ea5ae65a02c'}, {'wins': 8, 'draws': 16, 'losses': 22, 'points': 40, 'matches': 46, 'team_id': 7896, 'position': 21, 'team_name': 'Gillingham', 'scores_for': 35, 'scores_against': 69, 'team_hash_image': '7cd94cdf477938774593b8581a87cf2ac2a9c61176cdc5ea034569ec6e8cfb29'}, {'wins': 10, 'draws': 8, 'losses': 28, 'points': 38, 'matches': 46, 'team_id': 7996, 'position': 22, 'team_name': 'Doncaster Rovers', 'scores_for': 37, 'scores_against': 82, 'team_hash_image': '403e17b026d8db7a8d1ecc3663750c5816cb4a920fa2a452f6059498800b7d90'}, {'wins': 10, 'draws': 12, 'losses': 24, 'points': 42, 'matches': 46, 'team_id': 7799, 'position': 19, 'team_name': 'Morecambe', 'scores_for': 57, 'scores_against': 88, 'team_hash_image': 'b9ac5fc7cc1571246c264fbc5ca39c4b28fe1de2aa9093bd68248d3d0969f02c'}, {'wins': 12, 'draws': 14, 'losses': 20, 'points': 50, 'matches': 46, 'team_id': 7117, 'position': 18, 'team_name': 'Shrewsbury Town', 'scores_for': 47, 'scores_against': 51, 'team_hash_image': '08924cb4f356ee51e6c50f9796e2a6c4182fbcd0d0ef7cedcd927bc371b3dd72'}, {'wins': 13, 'draws': 17, 'losses': 16, 'points': 56, 'matches': 46, 'team_id': 7812, 'position': 15, 'team_name': 'Cheltenham Town', 'scores_for': 66, 'scores_against': 80, 'team_hash_image': '19c659e7c9f3a162af51d6212735f4e03f4db96a2202a9fa06cf9d3aceed78dc'}, {'wins': 14, 'draws': 10, 'losses': 22, 'points': 52, 'matches': 46, 'team_id': 7543, 'position': 17, 'team_name': 'Lincoln City', 'scores_for': 55, 'scores_against': 63, 'team_hash_image': '63b905f3235067ef7446ed93573927fdd4046d58fb2893119e4be376791c462b'}, {'wins': 14, 'draws': 11, 'losses': 21, 'points': 53, 'matches': 46, 'team_id': 7225, 'position': 16, 'team_name': 'Burton Albion', 'scores_for': 51, 'scores_against': 67, 'team_hash_image': 'c7c46048703aace97a6c53fa194d9543f7581ec7af49c0fe375561750076e68d'}, {'wins': 15, 'draws': 13, 'losses': 18, 'points': 58, 'matches': 46, 'team_id': 7385, 'position': 14, 'team_name': 'Cambridge United', 'scores_for': 56, 'scores_against': 74, 'team_hash_image': 'db018f2b74d4244cb117b1a72c07cfb8d73e3677d7bd2a2da0c8b787da98fe0b'}, {'wins': 17, 'draws': 8, 'losses': 21, 'points': 59, 'matches': 46, 'team_id': 4511, 'position': 13, 'team_name': 'Charlton Athletic', 'scores_for': 55, 'scores_against': 59, 'team_hash_image': '323dbb6366850550d0e7a0cbeb4e51c31bb88ed596bb006bea4de2e15fae6e04'}, {'wins': 17, 'draws': 10, 'losses': 19, 'points': 61, 'matches': 46, 'team_id': 7989, 'position': 12, 'team_name': 'Accrington Stanley', 'scores_for': 61, 'scores_against': 80, 'team_hash_image': 'b1c92a4342ab17f8b72b02b7e981a4ca88d52b651e9465a51cfb365ede934f99'}, {'wins': 18, 'draws': 16, 'losses': 12, 'points': 70, 'matches': 46, 'team_id': 4364, 'position': 11, 'team_name': 'Ipswich Town', 'scores_for': 67, 'scores_against': 46, 'team_hash_image': 'e8a89aac97ce210544749edf3e268b36a27d68d5bcc2c8104bfd0587e60f345d'}, {'wins': 20, 'draws': 13, 'losses': 13, 'points': 73, 'matches': 46, 'team ...
# {'id': 16721, 'tournament_id': 70, 'type': 'total', 'name': 'League One 22/23', 'season_id': 1762, 'season_name': 'League One 22/23', 'league_id': 166, 'league_name': 'League One', 'league_hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'competitors': [{'wins': 6, 'draws': 9, 'losses': 31, 'points': 27, 'matches': 46, 'team_id': 4443, 'position': 24, 'team_name': 'Forest Green Rovers', 'scores_for': 31, 'scores_against': 89, 'team_hash_image': '2f52d9070fea52611845290bacc429f75c0a599a6afc227e57757245eb294143'}, {'wins': 10, 'draws': 14, 'losses': 22, 'points': 44, 'matches': 46, 'team_id': 7799, 'position': 22, 'team_name': 'Morecambe', 'scores_for': 47, 'scores_against': 78, 'team_hash_image': 'b9ac5fc7cc1571246c264fbc5ca39c4b28fe1de2aa9093bd68248d3d0969f02c'}, {'wins': 11, 'draws': 11, 'losses': 24, 'points': 44, 'matches': 46, 'team_id': 7989, 'position': 23, 'team_name': 'Accrington Stanley', 'scores_for': 40, 'scores_against': 77, 'team_hash_image': 'b1c92a4342ab17f8b72b02b7e981a4ca88d52b651e9465a51cfb365ede934f99'}, {'wins': 11, 'draws': 12, 'losses': 23, 'points': 45, 'matches': 46, 'team_id': 8201, 'position': 21, 'team_name': 'Milton Keynes Dons', 'scores_for': 44, 'scores_against': 66, 'team_hash_image': '52ae4e5b6dde4565d559ceb133552ed3f1b64d58bbd13d621629463f9b3cd6fd'}, {'wins': 11, 'draws': 14, 'losses': 21, 'points': 47, 'matches': 46, 'team_id': 6940, 'position': 19, 'team_name': 'Oxford United', 'scores_for': 49, 'scores_against': 56, 'team_hash_image': '8803e6beed24526b54b46ba8214cec4a8b07367b02f8b7fe42d64c4f918cef81'}, {'wins': 13, 'draws': 7, 'losses': 26, 'points': 46, 'matches': 46, 'team_id': 7385, 'position': 20, 'team_name': 'Cambridge United', 'scores_for': 41, 'scores_against': 68, 'team_hash_image': 'db018f2b74d4244cb117b1a72c07cfb8d73e3677d7bd2a2da0c8b787da98fe0b'}, {'wins': 13, 'draws': 10, 'losses': 23, 'points': 49, 'matches': 46, 'team_id': 7686, 'position': 18, 'team_name': 'Port Vale', 'scores_for': 48, 'scores_against': 71, 'team_hash_image': '9ab8fb3c1370302739562accc8455d39c2e2f9458e973c6b824ead0010cc2eff'}, {'wins': 14, 'draws': 11, 'losses': 21, 'points': 53, 'matches': 46, 'team_id': 4333, 'position': 17, 'team_name': 'Bristol Rovers', 'scores_for': 58, 'scores_against': 73, 'team_hash_image': 'fe006e276961ff8604e5ff484ca34365e1215e2e5c236e81cc2f724b94b7259b'}, {'wins': 14, 'draws': 12, 'losses': 20, 'points': 54, 'matches': 46, 'team_id': 7812, 'position': 16, 'team_name': 'Cheltenham Town', 'scores_for': 45, 'scores_against': 61, 'team_hash_image': '19c659e7c9f3a162af51d6212735f4e03f4db96a2202a9fa06cf9d3aceed78dc'}, {'wins': 14, 'draws': 16, 'losses': 16, 'points': 58, 'matches': 46, 'team_id': 7518, 'position': 13, 'team_name': 'Fleetwood Town', 'scores_for': 53, 'scores_against': 51, 'team_hash_image': '48f74a3d52341d622a41d796658133182360d10ebdefc093f6268ea5ae65a02c'}, {'wins': 14, 'draws': 20, 'losses': 12, 'points': 62, 'matches': 46, 'team_id': 7543, 'position': 11, 'team_name': 'Lincoln City', 'scores_for': 47, 'scores_against': 47, 'team_hash_image': '63b905f3235067ef7446ed93573927fdd4046d58fb2893119e4be376791c462b'}, {'wins': 15, 'draws': 11, 'losses': 20, 'points': 56, 'matches': 46, 'team_id': 4478, 'position': 14, 'team_name': 'Exeter City', 'scores_for': 64, 'scores_against': 68, 'team_hash_image': 'd354cd9c3b70770d13964e926e4cf7268cd423cdf71026967529e11351408210'}, {'wins': 15, 'draws': 11, 'losses': 20, 'points': 56, 'matches': 46, 'team_id': 7225, 'position': 15, 'team_name': 'Burton Albion', 'scores_for': 57, 'scores_against': 79, 'team_hash_image': 'c7c46048703aace97a6c53fa194d9543f7581ec7af49c0fe375561750076e68d'}, {'wins': 16, 'draws': 14, 'losses': 16, 'points': 62, 'matches': 46, 'team_id': 4511, 'position': 10, 'team_name': 'Charlton Athletic', 'scores_for': 70, 'scores_against': 66, 'team_hash_image': '323dbb6366850550d0e7a0cbeb4e51c31bb88ed596bb006bea4de2e15fae6e04'}, {'wins': 17, 'draws': 8, 'losses': 21, 'points': 59, 'matches ...
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 599
# {'id': 1128, 'tournament_id': 70, 'type': 'total', 'name': 'League One', 'season_id': 2875, 'season_name': 'League One 12/13', 'league_id': 166, 'league_name': 'League One', 'league_hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'competitors': [{'wins': 9, 'draws': 14, 'losses': 23, 'points': 41, 'matches': 46, 'team_id': 4401, 'position': 23, 'team_name': 'Hartlepool United', 'scores_for': 39, 'scores_against': 67, 'team_hash_image': '316897ddb25ccc206a9996ea7de1a7624ec72bbe4f9da152a54c52f3a4cb5a00'}, {'wins': 9, 'draws': 14, 'losses': 23, 'points': 41, 'matches': 46, 'team_id': 8515, 'position': 22, 'team_name': 'Bury AFC', 'scores_for': 45, 'scores_against': 73, 'team_hash_image': '71a647a3b2aba958f5357aa23c32d1540aa9f844996acffcbfbbdd7e9a647b79'}, {'wins': 10, 'draws': 12, 'losses': 24, 'points': 32, 'matches': 46, 'team_id': 4296, 'position': 24, 'team_name': 'Portsmouth', 'scores_for': 51, 'scores_against': 69, 'team_hash_image': 'd1e01014a47db9d9d8bc12dfa02886979294e37b81e81bcf1fe2b35b674eb69d'}, {'wins': 13, 'draws': 9, 'losses': 24, 'points': 48, 'matches': 46, 'team_id': 4564, 'position': 21, 'team_name': 'Scunthorpe United', 'scores_for': 49, 'scores_against': 73, 'team_hash_image': 'e4ec0e6d57e34566dfb7f879a73f9ddef12f6be8da41f14077da50e4e389217c'}, {'wins': 13, 'draws': 16, 'losses': 17, 'points': 55, 'matches': 46, 'team_id': 7117, 'position': 16, 'team_name': 'Shrewsbury Town', 'scores_for': 54, 'scores_against': 60, 'team_hash_image': '08924cb4f356ee51e6c50f9796e2a6c4182fbcd0d0ef7cedcd927bc371b3dd72'}, {'wins': 14, 'draws': 9, 'losses': 23, 'points': 51, 'matches': 46, 'team_id': 7991, 'position': 20, 'team_name': 'Colchester United', 'scores_for': 47, 'scores_against': 68, 'team_hash_image': '7bbb33a7a87aed13cd4edc16a7141a3c60e4e8e3d6bf7e7a1d4ee235779c3347'}, {'wins': 14, 'draws': 9, 'losses': 23, 'points': 51, 'matches': 46, 'team_id': 8020, 'position': 19, 'team_name': 'Oldham Athletic', 'scores_for': 46, 'scores_against': 59, 'team_hash_image': '77d19813ea1cd72114970e1407517cdb5b9e6839a590563c56fcd73e801f4ccb'}, {'wins': 14, 'draws': 13, 'losses': 19, 'points': 55, 'matches': 46, 'team_id': 4325, 'position': 17, 'team_name': 'Carlisle United', 'scores_for': 56, 'scores_against': 77, 'team_hash_image': '04e2714fdeba28c3ca4e4e24454b82b19d0714652d474e5374f043846c19a160'}, {'wins': 14, 'draws': 17, 'losses': 15, 'points': 59, 'matches': 46, 'team_id': 8411, 'position': 14, 'team_name': 'Preston North End', 'scores_for': 54, 'scores_against': 49, 'team_hash_image': 'b9bc7368e3fbf3b5477f85ed028d5a6204592e40d8f68b4b6072995f741117ef'}, {'wins': 15, 'draws': 9, 'losses': 22, 'points': 54, 'matches': 46, 'team_id': 4298, 'position': 18, 'team_name': 'Stevenage', 'scores_for': 47, 'scores_against': 64, 'team_hash_image': 'e9f1fa960b8ff5769a0edc433be1e4c1dcd2d1c5c2a251f0bdf0a72ce7386e33'}, {'wins': 16, 'draws': 17, 'losses': 13, 'points': 65, 'matches': 46, 'team_id': 4041, 'position': 12, 'team_name': 'Notts County', 'scores_for': 61, 'scores_against': 49, 'team_hash_image': '24548edf86064af8e8c29afcfb4469ee5948c0b6ba9634683e3ae629ef067eba'}, {'wins': 17, 'draws': 17, 'losses': 12, 'points': 68, 'matches': 46, 'team_id': 4581, 'position': 9, 'team_name': 'Walsall', 'scores_for': 65, 'scores_against': 58, 'team_hash_image': '7b2d4e565f525cf48ea8f4c719d7af05ea1f96fa6aff5497056daa3d644d08a0'}, {'wins': 18, 'draws': 10, 'losses': 18, 'points': 64, 'matches': 46, 'team_id': 4534, 'position': 13, 'team_name': 'Crewe Alexandra', 'scores_for': 54, 'scores_against': 62, 'team_hash_image': 'ff8f313b6e8a7def03299289670e41461ad7a8a9ce2f9dda11e2d685a4f4b26a'}, {'wins': 18, 'draws': 11, 'losses': 17, 'points': 55, 'matches': 46, 'team_id': 4538, 'position': 15, 'team_name': 'Coventry City', 'scores_for': 66, 'scores_against': 59, 'team_hash_image': 'c58b7625cde7b4cb651d8b983b87516943368ab96564c39c329be338e098c171'}, {'wins': 18, 'draws': 14, 'losses': 14, 'points': 68, 'matches': 46, 'team_id': 787 ...
# ...
# {'id': 40044, 'tournament_id': 70, 'type': 'total', 'name': 'League One', 'season_id': 2644, 'season_name': 'League One 19/20', 'league_id': 166, 'league_name': 'League One', 'league_hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'competitors': [{'wins': 4, 'draws': 7, 'losses': 24, 'points': 19, 'matches': 35, 'team_id': 4444, 'position': 22, 'team_name': 'Southend United', 'scores_for': 39, 'scores_against': 85, 'team_hash_image': '373559cc127e87a6adb7dd2dc90ad9b35121313e05319ab82a228ea3c7ebd689'}, {'wins': 5, 'draws': 11, 'losses': 18, 'points': 14, 'matches': 34, 'team_id': 153, 'position': 23, 'team_name': 'Bolton Wanderers', 'scores_for': 27, 'scores_against': 66, 'team_hash_image': '11f8b6f90a3c5f2100acfdc78892c1a2bba4cdcb0ac550c6ef9219ff501bde96'}, {'wins': 8, 'draws': 8, 'losses': 18, 'points': 32, 'matches': 34, 'team_id': 4460, 'position': 21, 'team_name': 'Tranmere Rovers', 'scores_for': 36, 'scores_against': 60, 'team_hash_image': 'd49a32711871cd446193dde2b4bf5e1a1a43d3a862525deb9495c3d022cff86a'}, {'wins': 8, 'draws': 11, 'losses': 16, 'points': 35, 'matches': 35, 'team_id': 8107, 'position': 20, 'team_name': 'AFC Wimbledon', 'scores_for': 39, 'scores_against': 52, 'team_hash_image': 'dcff6df928b63ac1779cf83354fb4c6f0dcfbb64c97b63ee0ed2e02ac09ecdf2'}, {'wins': 10, 'draws': 6, 'losses': 18, 'points': 36, 'matches': 34, 'team_id': 4370, 'position': 18, 'team_name': 'Rochdale', 'scores_for': 39, 'scores_against': 57, 'team_hash_image': '96f0f08dba8ca5c46830dd7f612c4ba586ef036b67a13686e981dc2ac443a397'}, {'wins': 10, 'draws': 7, 'losses': 18, 'points': 37, 'matches': 35, 'team_id': 8201, 'position': 19, 'team_name': 'Milton Keynes Dons', 'scores_for': 36, 'scores_against': 47, 'team_hash_image': '52ae4e5b6dde4565d559ceb133552ed3f1b64d58bbd13d621629463f9b3cd6fd'}, {'wins': 10, 'draws': 10, 'losses': 15, 'points': 40, 'matches': 35, 'team_id': 7989, 'position': 17, 'team_name': 'Accrington Stanley', 'scores_for': 47, 'scores_against': 53, 'team_hash_image': 'b1c92a4342ab17f8b72b02b7e981a4ca88d52b651e9465a51cfb365ede934f99'}, {'wins': 10, 'draws': 11, 'losses': 13, 'points': 41, 'matches': 34, 'team_id': 7117, 'position': 15, 'team_name': 'Shrewsbury Town', 'scores_for': 31, 'scores_against': 42, 'team_hash_image': '08924cb4f356ee51e6c50f9796e2a6c4182fbcd0d0ef7cedcd927bc371b3dd72'}, {'wins': 11, 'draws': 12, 'losses': 12, 'points': 45, 'matches': 35, 'team_id': 4225, 'position': 13, 'team_name': 'Blackpool', 'scores_for': 44, 'scores_against': 43, 'team_hash_image': '8f774c61545c0969475e9454f6ccb9d088d55deff289ab276cb1b416342bdd22'}, {'wins': 12, 'draws': 6, 'losses': 17, 'points': 42, 'matches': 35, 'team_id': 7543, 'position': 16, 'team_name': 'Lincoln City', 'scores_for': 44, 'scores_against': 46, 'team_hash_image': '63b905f3235067ef7446ed93573927fdd4046d58fb2893119e4be376791c462b'}, {'wins': 12, 'draws': 9, 'losses': 14, 'points': 45, 'matches': 35, 'team_id': 4333, 'position': 14, 'team_name': 'Bristol Rovers', 'scores_for': 38, 'scores_against': 49, 'team_hash_image': 'fe006e276961ff8604e5ff484ca34365e1215e2e5c236e81cc2f724b94b7259b'}, {'wins': 12, 'draws': 12, 'losses': 11, 'points': 48, 'matches': 35, 'team_id': 7225, 'position': 12, 'team_name': 'Burton Albion', 'scores_for': 50, 'scores_against': 50, 'team_hash_image': 'c7c46048703aace97a6c53fa194d9543f7581ec7af49c0fe375561750076e68d'}, {'wins': 12, 'draws': 15, 'losses': 8, 'points': 51, 'matches': 35, 'team_id': 7896, 'position': 10, 'team_name': 'Gillingham', 'scores_for': 42, 'scores_against': 34, 'team_hash_image': '7cd94cdf477938774593b8581a87cf2ac2a9c61176cdc5ea034569ec6e8cfb29'}, {'wins': 14, 'draws': 10, 'losses': 12, 'points': 52, 'matches': 36, 'team_id': 4364, 'position': 11, 'team_name': 'Ipswich Town', 'scores_for': 46, 'scores_against': 36, 'team_hash_image': 'e8a89aac97ce210544749edf3e268b36a27d68d5bcc2c8104bfd0587e60f345d'}, {'wins': 15, 'draws': 9, 'losses': 10, 'points': 54, 'matches': 34, 'team_id': 7996, ' ...
# {'id': 17407, 'tournament_id': 70, 'type': 'total', 'name': 'League One', 'season_id': 2952, 'season_name': 'League One 10/11', 'league_id': 166, 'league_name': 'League One', 'league_hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'competitors': [{'wins': 9, 'draws': 14, 'losses': 23, 'points': 41, 'matches': 46, 'team_id': 148, 'position': 24, 'team_name': 'Swindon Town', 'scores_for': 50, 'scores_against': 72, 'team_hash_image': 'b042866e1bf49a33a9c47ffa179822ee3349be98b879d95d16477018ef3d3431'}, {'wins': 11, 'draws': 12, 'losses': 23, 'points': 45, 'matches': 46, 'team_id': 4333, 'position': 22, 'team_name': 'Bristol Rovers', 'scores_for': 48, 'scores_against': 82, 'team_hash_image': 'fe006e276961ff8604e5ff484ca34365e1215e2e5c236e81cc2f724b94b7259b'}, {'wins': 12, 'draws': 11, 'losses': 23, 'points': 47, 'matches': 46, 'team_id': 14281, 'position': 21, 'team_name': 'Dagenham & Redbridge', 'scores_for': 52, 'scores_against': 70, 'team_hash_image': '96b976ffbfbbe637fa1fb447aa9244524f345eba46a1faf23dea6469c2cbd62e'}, {'wins': 12, 'draws': 12, 'losses': 22, 'points': 48, 'matches': 46, 'team_id': 4581, 'position': 20, 'team_name': 'Walsall', 'scores_for': 56, 'scores_against': 75, 'team_hash_image': '7b2d4e565f525cf48ea8f4c719d7af05ea1f96fa6aff5497056daa3d644d08a0'}, {'wins': 13, 'draws': 17, 'losses': 16, 'points': 56, 'matches': 46, 'team_id': 8020, 'position': 17, 'team_name': 'Oldham Athletic', 'scores_for': 53, 'scores_against': 60, 'team_hash_image': '77d19813ea1cd72114970e1407517cdb5b9e6839a590563c56fcd73e801f4ccb'}, {'wins': 14, 'draws': 8, 'losses': 24, 'points': 50, 'matches': 46, 'team_id': 4041, 'position': 19, 'team_name': 'Notts County', 'scores_for': 46, 'scores_against': 60, 'team_hash_image': '24548edf86064af8e8c29afcfb4469ee5948c0b6ba9634683e3ae629ef067eba'}, {'wins': 15, 'draws': 7, 'losses': 24, 'points': 42, 'matches': 46, 'team_id': 4331, 'position': 23, 'team_name': 'Plymouth Argyle', 'scores_for': 51, 'scores_against': 74, 'team_hash_image': '28a1af2f1c858497a9c3588c65d0777e489adaa78bfce544973fffd21c076c7f'}, {'wins': 15, 'draws': 11, 'losses': 20, 'points': 56, 'matches': 46, 'team_id': 4460, 'position': 17, 'team_name': 'Tranmere Rovers', 'scores_for': 53, 'scores_against': 60, 'team_hash_image': 'd49a32711871cd446193dde2b4bf5e1a1a43d3a862525deb9495c3d022cff86a'}, {'wins': 15, 'draws': 12, 'losses': 19, 'points': 57, 'matches': 46, 'team_id': 4401, 'position': 16, 'team_name': 'Hartlepool United', 'scores_for': 47, 'scores_against': 65, 'team_hash_image': '316897ddb25ccc206a9996ea7de1a7624ec72bbe4f9da152a54c52f3a4cb5a00'}, {'wins': 15, 'draws': 14, 'losses': 17, 'points': 59, 'matches': 46, 'team_id': 4511, 'position': 13, 'team_name': 'Charlton Athletic', 'scores_for': 62, 'scores_against': 66, 'team_hash_image': '323dbb6366850550d0e7a0cbeb4e51c31bb88ed596bb006bea4de2e15fae6e04'}, {'wins': 16, 'draws': 10, 'losses': 20, 'points': 58, 'matches': 46, 'team_id': 4397, 'position': 15, 'team_name': 'Sheffield Wednesday', 'scores_for': 67, 'scores_against': 67, 'team_hash_image': '8d0f363e39bdaf510648a78d746887ff750f8622c419ac63bd7db13407946a23'}, {'wins': 16, 'draws': 11, 'losses': 19, 'points': 59, 'matches': 46, 'team_id': 4065, 'position': 14, 'team_name': 'Yeovil Town', 'scores_for': 56, 'scores_against': 66, 'team_hash_image': 'c9c1976e517fc74b065f524ef84ad68b5bb2d6f3257772df9f5d3bb0f306d509'}, {'wins': 16, 'draws': 11, 'losses': 19, 'points': 59, 'matches': 46, 'team_id': 4325, 'position': 12, 'team_name': 'Carlisle United', 'scores_for': 60, 'scores_against': 62, 'team_hash_image': '04e2714fdeba28c3ca4e4e24454b82b19d0714652d474e5374f043846c19a160'}, {'wins': 16, 'draws': 14, 'losses': 16, 'points': 62, 'matches': 46, 'team_id': 7991, 'position': 10, 'team_name': 'Colchester United', 'scores_for': 57, 'scores_against': 63, 'team_hash_image': '7bbb33a7a87aed13cd4edc16a7141a3c60e4e8e3d6bf7e7a1d4ee235779c3347'}, {'wins': 17, 'draws': 10, 'losses': 19, 'points': 61, 'matc ...
# {'id': 92615, 'tournament_id': 70, 'tournament_name': 'League One', 'type': 'total', 'name': 'League One', 'season_id': 1323, 'season_name': 'League One 23/24', 'league_id': 166, 'league_name': 'League One', 'league_hash_image': '76c73452d3ab3358bae53e90790bc217bc687a4869b7ad6bb7406f75a77a67e2', 'competitors': [{'wins': 7, 'draws': 16, 'losses': 30, 'points': 30, 'matches': 46, 'team_id': 4325, 'position': 24, 'team_name': 'Carlisle United', 'scores_for': 41, 'scores_against': 81, 'team_hash_image': '04e2714fdeba28c3ca4e4e24454b82b19d0714652d474e5374f043846c19a160'}, {'wins': 10, 'draws': 16, 'losses': 25, 'points': 41, 'matches': 46, 'team_id': 7686, 'position': 23, 'team_name': 'Port Vale', 'scores_for': 41, 'scores_against': 74, 'team_hash_image': '9ab8fb3c1370302739562accc8455d39c2e2f9458e973c6b824ead0010cc2eff'}, {'wins': 10, 'draws': 20, 'losses': 23, 'points': 43, 'matches': 46, 'team_id': 7518, 'position': 22, 'team_name': 'Fleetwood Town', 'scores_for': 49, 'scores_against': 72, 'team_hash_image': '48f74a3d52341d622a41d796658133182360d10ebdefc093f6268ea5ae65a02c'}, {'wins': 11, 'draws': 10, 'losses': 15, 'points': 53, 'matches': 46, 'team_id': 4511, 'position': 16, 'team_name': 'Charlton Athletic', 'scores_for': 64, 'scores_against': 65, 'team_hash_image': '323dbb6366850550d0e7a0cbeb4e51c31bb88ed596bb006bea4de2e15fae6e04'}, {'wins': 12, 'draws': 4, 'losses': 22, 'points': 48, 'matches': 46, 'team_id': 7385, 'position': 18, 'team_name': 'Cambridge United', 'scores_for': 39, 'scores_against': 61, 'team_hash_image': 'db018f2b74d4244cb117b1a72c07cfb8d73e3677d7bd2a2da0c8b787da98fe0b'}, {'wins': 12, 'draws': 10, 'losses': 24, 'points': 46, 'matches': 46, 'team_id': 7225, 'position': 20, 'team_name': 'Burton Albion', 'scores_for': 39, 'scores_against': 67, 'team_hash_image': 'c7c46048703aace97a6c53fa194d9543f7581ec7af49c0fe375561750076e68d'}, {'wins': 12, 'draws': 12, 'losses': 26, 'points': 44, 'matches': 46, 'team_id': 7812, 'position': 21, 'team_name': 'Cheltenham Town', 'scores_for': 41, 'scores_against': 65, 'team_hash_image': '19c659e7c9f3a162af51d6212735f4e03f4db96a2202a9fa06cf9d3aceed78dc'}, {'wins': 13, 'draws': 6, 'losses': 24, 'points': 48, 'matches': 46, 'team_id': 7117, 'position': 19, 'team_name': 'Shrewsbury Town', 'scores_for': 35, 'scores_against': 67, 'team_hash_image': '08924cb4f356ee51e6c50f9796e2a6c4182fbcd0d0ef7cedcd927bc371b3dd72'}, {'wins': 16, 'draws': 0, 'losses': 21, 'points': 57, 'matches': 46, 'team_id': 4333, 'position': 15, 'team_name': 'Bristol Rovers', 'scores_for': 52, 'scores_against': 68, 'team_hash_image': 'fe006e276961ff8604e5ff484ca34365e1215e2e5c236e81cc2f724b94b7259b'}, {'wins': 16, 'draws': 10, 'losses': 19, 'points': 53, 'matches': 46, 'team_id': 170, 'position': 17, 'team_name': 'Reading', 'scores_for': 68, 'scores_against': 70, 'team_hash_image': 'e1f0b23a2a31e509015b6243b066927c475c286632946a22932df9b4bea6c8fb'}, {'wins': 17, 'draws': 4, 'losses': 20, 'points': 60, 'matches': 46, 'team_id': 4284, 'position': 14, 'team_name': 'Northampton Town', 'scores_for': 57, 'scores_against': 66, 'team_hash_image': '6cc9fdc88a980621719b8f5cd079c944d839fd44863dfcca158d47e22cd89c7a'}, {'wins': 17, 'draws': 8, 'losses': 15, 'points': 65, 'matches': 46, 'team_id': 4559, 'position': 10, 'team_name': 'Wycombe Wanderers', 'scores_for': 60, 'scores_against': 55, 'team_hash_image': 'b95a035bf0e7860f20d604aa8784550a1550e556211a1374179025bf6dc3c50a'}, {'wins': 17, 'draws': 12, 'losses': 19, 'points': 61, 'matches': 46, 'team_id': 4478, 'position': 13, 'team_name': 'Exeter City', 'scores_for': 46, 'scores_against': 61, 'team_hash_image': 'd354cd9c3b70770d13964e926e4cf7268cd423cdf71026967529e11351408210'}, {'wins': 18, 'draws': 18, 'losses': 17, 'points': 65, 'matches': 46, 'team_id': 4256, 'position': 11, 'team_name': 'Leyton Orient', 'scores_for': 53, 'scores_against': 55, 'team_hash_image': '02c60245ad65c53763986dbf71c2f32c9e13acbd7018a6775c284939e0697c4c'}, {'wins': 19, 'draws': 18, 'losses': 13, 'poi ...
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 620
# Total seasons: 16
# Total mactches: 9362
# Total line up ids: 8650

# %%
# Load seasons file to BIQ QUERY extract_layer seasons table

# Set the dataset and table name
dataset_name = 'extract_layer'
table_name = 'api_sportdevs_fb_seasons'
table_ref = client.dataset(dataset_name).table(table_name)

# Load the final data file into the BiqQuery table
job_config = bigquery.LoadJobConfig(
  source_format=bigquery.SourceFormat.NEWLINE_DELIMITED_JSON,
  write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,
  autodetect=True
)

with open(f"{league_name}_seasons_data.json", 'rb') as lineups_file:
              job = client.load_table_from_file(
                    lineups_file, table_ref, job_config=job_config
                )
# Wait for the job to complete
job.result()
total_rows = job.output_rows
print(f"Big Query Rows {total_rows} processed into {dataset_name}.{table_name}")
# Out:
# Big Query Rows 16 processed into extract_layer.api_sportdevs_fb_seasons

# %%
# Load seasons data into BIQ QUERY load_layer seasons table

# Set the target load dataset and table names
load_dataset_name = 'load_layer'
load_table_name = 'all_api_sportdevs_fb_seasons'
table_ref = client.dataset(load_dataset_name).table(load_table_name)

# Delete rows already inserted
delete_query = f"DELETE FROM `{load_dataset_name}.{load_table_name}` WHERE id IN (SELECT DISTINCT id FROM `{dataset_name}.{table_name}`)"
delete_job = client.query(delete_query)
delete_result = delete_job.result()
total_rows_deleted = delete_result.num_dml_affected_rows

if total_rows_deleted == 0:
    print(f"No rows were deleted from {load_dataset_name}.{load_table_name}.")
else:
   print(f"Total rows deleted from {load_dataset_name}.{load_table_name}: {total_rows_deleted}")

# Define the load job configuration
job_config = bigquery.QueryJobConfig(
    destination=table_ref,
    write_disposition=bigquery.WriteDisposition.WRITE_APPEND,
    schema_update_options=[
        bigquery.SchemaUpdateOption.ALLOW_FIELD_ADDITION
    ]
)

# Define the SQL query
insert_query = f"SELECT * FROM `{dataset_name}.{table_name}`"

# Run the load job and wait for the job to complete
load_job = client.query(insert_query, job_config=job_config)
job.result()
total_rows = job.output_rows
print(f"Big Query Rows {total_rows} processed into {load_dataset_name}.{load_table_name}")
# Out:
# Total rows deleted from load_layer.all_api_sportdevs_fb_seasons: 16
# Big Query Rows 16 processed into load_layer.all_api_sportdevs_fb_seasons

# %%
# Load standings teams file to BIQ QUERY extract_layer season teams table

# Set the dataset and table name
dataset_name = 'extract_layer'
table_name = 'api_sportdevs_fb_standings'
table_ref = client.dataset(dataset_name).table(table_name)

# Load the final data file into the BiqQuery table
job_config = bigquery.LoadJobConfig(
  source_format=bigquery.SourceFormat.NEWLINE_DELIMITED_JSON,
  write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,
  autodetect=True
)

with open(f"{league_name}_season_standings_data.json", 'rb') as lineups_file:
              job = client.load_table_from_file(
                    lineups_file, table_ref, job_config=job_config
                )
# Wait for the job to complete
job.result()
total_rows = job.output_rows
print(f"Big Query Rows {total_rows} processed into {dataset_name}.{table_name}")
# Out:
# Big Query Rows 16 processed into extract_layer.api_sportdevs_fb_standings

# %%
# Load standings data into BIQ QUERY load_layer season teams table

# Set the target load dataset and table names
load_dataset_name = 'load_layer'
load_table_name = 'all_api_sportdevs_fb_standings'
table_ref = client.dataset(load_dataset_name).table(load_table_name)

# Delete rows already inserted
delete_query = f"DELETE FROM `{load_dataset_name}.{load_table_name}` WHERE id IN (SELECT DISTINCT id FROM `{dataset_name}.{table_name}`)"
delete_job = client.query(delete_query)
delete_result = delete_job.result()
total_rows_deleted = delete_result.num_dml_affected_rows

if total_rows_deleted == 0:
    print(f"No rows were deleted from {load_dataset_name}.{load_table_name}.")
else:
   print(f"Total rows deleted from {load_dataset_name}.{load_table_name}: {total_rows_deleted}")

# Define the load job configuration
job_config = bigquery.QueryJobConfig(
    destination=table_ref,
    write_disposition=bigquery.WriteDisposition.WRITE_APPEND,
    schema_update_options=[
        bigquery.SchemaUpdateOption.ALLOW_FIELD_ADDITION
    ]
)

# Define the SQL query
insert_query = f"SELECT * FROM `{dataset_name}.{table_name}`"

# Run the load job and wait for the job to complete
load_job = client.query(insert_query, job_config=job_config)
job.result()
total_rows = job.output_rows
print(f"Big Query Rows {total_rows} processed into {load_dataset_name}.{load_table_name}")
# Out:
# Total rows deleted from load_layer.all_api_sportdevs_fb_standings: 4
# Big Query Rows 16 processed into load_layer.all_api_sportdevs_fb_standings

# %%
# Load matches file to BIQ QUERY extract_layer matches table

# Set the dataset and table names
dataset_name = 'extract_layer'
table_name = 'api_sportdevs_fb_matches'
table_ref = client.dataset(dataset_name).table(table_name)

#table = client.get_table(table_ref)

# Truncate the table to remove all existing rows
client.query(f"TRUNCATE TABLE `{dataset_name}.{table_name}`").result()


# Load the final data file into the BiqQuery table
job_config = bigquery.LoadJobConfig(
  source_format=bigquery.SourceFormat.NEWLINE_DELIMITED_JSON,
  write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,
  autodetect=True
)

with open(f"{league_name}_matches_data.json", 'rb') as lineups_file:
              job = client.load_table_from_file(
                    lineups_file, table_ref, job_config=job_config
                )
# Wait for the job to complete
job.result()
total_rows = job.output_rows
print(f"Big Query Rows {total_rows} processed into {dataset_name}.{table_name}")
# Out:
# Big Query Rows 9362 processed into extract_layer.api_sportdevs_fb_matches

# %%
# Load matches extract data into BIQ QUERY load_layer matches table

# Set the table reference
load_dataset_name = 'load_layer'
load_table_name = 'all_api_sportdevs_fb_matches'
table_ref = client.dataset(load_dataset_name).table(load_table_name)

# Delete rows already inserted
delete_query = f"DELETE FROM `{load_dataset_name}.{load_table_name}` WHERE id IN (SELECT DISTINCT id FROM `{dataset_name}.{table_name}`)"
delete_job = client.query(delete_query)
delete_result = delete_job.result()
total_rows_deleted = delete_result.num_dml_affected_rows

if total_rows_deleted == 0:
    print(f"No rows were deleted from {load_dataset_name}.{load_table_name}.")
else:
   print(f"Total rows deleted from {load_dataset_name}.{load_table_name}: {total_rows_deleted}")

# Define the load job configuration
job_config = bigquery.QueryJobConfig(
    destination=table_ref,
    write_disposition=bigquery.WriteDisposition.WRITE_APPEND,
    schema_update_options=[
        bigquery.SchemaUpdateOption.ALLOW_FIELD_ADDITION
    ]
)

# Define the SQL query
insert_query = f"SELECT * FROM `{dataset_name}.{table_name}`"

# Run the load job and wait for the job to complete
load_job = client.query(insert_query, job_config=job_config)

# Wait for the job to complete
job.result()
total_rows = job.output_rows
print(f"Big Query Rows {total_rows} processed into {load_dataset_name}.{load_table_name}")
# Out:
# Total rows deleted from load_layer.all_api_sportdevs_fb_matches: 8179
# Big Query Rows 9362 processed into load_layer.all_api_sportdevs_fb_matches

# %%
# Create and write to line ups file extract data into BIQ QUERY extract_layer lineups table

# Set the target dataset and table names
dataset_name = 'extract_layer'
table_name = 'api_sportdevs_fb_lineups'
table_ref = client.dataset(dataset_name).table(table_name)

def send_requests_in_batches(ids, api_endpoint, batch_size=50):
    total_ids = len(ids)
    total_batches = math.ceil(total_ids / batch_size)
    print(f"Total ids: {total_ids}")
    print(f"Total batches: {total_batches}")

    batches = [ids[i:i+batch_size] for i in range(0, len(ids), batch_size)]
    batch_count = 1

    with open(f"{league_name}_lineups_data.json", 'w') as lineups_file:
        for batch in batches:
            batch_ids = ','.join(map(str, batch))
            url = f"{api_endpoint}?id=in.({batch_ids})"
            response = requests.get(url, headers=headers)
            lineups_data = response.json()

            # Prepare the data to be inserted
            for lineup in lineups_data:
                lineups_file.write(json.dumps(lineup) + '\n')

            print(f"API Batch {batch_count}/{total_batches} processed.")

            batch_count += 1

# Call batch requests function
ids = lineup_ids
api_endpoint = "https://football.sportdevs.com/matches-lineups"
send_requests_in_batches(ids, api_endpoint)

# Load the final extract data file into the BIGQUERY table
job_config = bigquery.LoadJobConfig(
  source_format=bigquery.SourceFormat.NEWLINE_DELIMITED_JSON,
  write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,
  autodetect=True
)

with open(f"{league_name}_lineups_data.json", 'rb') as lineups_file:
              job = client.load_table_from_file(
                    lineups_file, table_ref, job_config=job_config
                )
# Wait for the job to complete and print message
job.result()
total_rows = job.output_rows
print(f"Big Query Rows {total_rows} processed into {dataset_name}.{table_name}.")
# Out:
# Total ids: 8650
# Total batches: 173
# API Batch 1/173 processed.
# API Batch 2/173 processed.
# API Batch 3/173 processed.
# API Batch 4/173 processed.
# API Batch 5/173 processed.
# API Batch 6/173 processed.
# API Batch 7/173 processed.
# API Batch 8/173 processed.
# API Batch 9/173 processed.
# API Batch 10/173 processed.
# API Batch 11/173 processed.
# API Batch 12/173 processed.
# API Batch 13/173 processed.
# API Batch 14/173 processed.
# API Batch 15/173 processed.
# API Batch 16/173 processed.
# API Batch 17/173 processed.
# API Batch 18/173 processed.
# API Batch 19/173 processed.
# API Batch 20/173 processed.
# API Batch 21/173 processed.
# API Batch 22/173 processed.
# API Batch 23/173 processed.
# API Batch 24/173 processed.
# API Batch 25/173 processed.
# API Batch 26/173 processed.
# API Batch 27/173 processed.
# API Batch 28/173 processed.
# API Batch 29/173 processed.
# API Batch 30/173 processed.
# API Batch 31/173 processed.
# API Batch 32/173 processed.
# API Batch 33/173 processed.
# API Batch 34/173 processed.
# API Batch 35/173 processed.
# API Batch 36/173 processed.
# API Batch 37/173 processed.
# API Batch 38/173 processed.
# API Batch 39/173 processed.
# API Batch 40/173 processed.
# API Batch 41/173 processed.
# API Batch 42/173 processed.
# API Batch 43/173 processed.
# API Batch 44/173 processed.
# API Batch 45/173 processed.
# API Batch 46/173 processed.
# API Batch 47/173 processed.
# API Batch 48/173 processed.
# API Batch 49/173 processed.
# API Batch 50/173 processed.
# API Batch 51/173 processed.
# API Batch 52/173 processed.
# API Batch 53/173 processed.
# API Batch 54/173 processed.
# API Batch 55/173 processed.
# API Batch 56/173 processed.
# API Batch 57/173 processed.
# API Batch 58/173 processed.
# API Batch 59/173 processed.
# API Batch 60/173 processed.
# API Batch 61/173 processed.
# API Batch 62/173 processed.
# API Batch 63/173 processed.
# API Batch 64/173 processed.
# API Batch 65/173 processed.
# API Batch 66/173 processed.
# API Batch 67/173 processed.
# API Batch 68/173 processed.
# API Batch 69/173 processed.
# API Batch 70/173 processed.
# API Batch 71/173 processed.
# API Batch 72/173 processed.
# API Batch 73/173 processed.
# API Batch 74/173 processed.
# API Batch 75/173 processed.
# API Batch 76/173 processed.
# API Batch 77/173 processed.
# API Batch 78/173 processed.
# API Batch 79/173 processed.
# API Batch 80/173 processed.
# API Batch 81/173 processed.
# API Batch 82/173 processed.
# API Batch 83/173 processed.
# API Batch 84/173 processed.
# API Batch 85/173 processed.
# API Batch 86/173 processed.
# API Batch 87/173 processed.
# API Batch 88/173 processed.
# API Batch 89/173 processed.
# API Batch 90/173 processed.
# API Batch 91/173 processed.
# API Batch 92/173 processed.
# API Batch 93/173 processed.
# API Batch 94/173 processed.
# API Batch 95/173 processed.
# API Batch 96/173 processed.
# API Batch 97/173 processed.
# API Batch 98/173 processed.
# API Batch 99/173 processed.
# API Batch 100/173 processed.
# API Batch 101/173 processed.
# API Batch 102/173 processed.
# API Batch 103/173 processed.
# API Batch 104/173 processed.
# API Batch 105/173 processed.
# API Batch 106/173 processed.
# API Batch 107/173 processed.
# API Batch 108/173 processed.
# API Batch 109/173 processed.
# API Batch 110/173 processed.
# API Batch 111/173 processed.
# API Batch 112/173 processed.
# API Batch 113/173 processed.
# API Batch 114/173 processed.
# API Batch 115/173 processed.
# API Batch 116/173 processed.
# API Batch 117/173 processed.
# API Batch 118/173 processed.
# API Batch 119/173 processed.
# API Batch 120/173 processed.
# API Batch 121/173 processed.
# API Batch 122/173 processed.
# API Batch 123/173 processed.
# API Batch 124/173 processed.
# API Batch 125/173 processed.
# API Batch 126/173 processed.
# API Batch 127/173 processed.
# API Batch 128/173 processed.
# API Batch 129/173 processed.
# API Batch 130/173 processed.
# API Batch 131/173 processed.
# API Batch 132/173 processed.
# API Batch 133/173 processed.
# API Batch 134/173 processed.
# API Batch 135/173 processed.
# API Batch 136/173 processed.
# API Batch 137/173 processed.
# API Batch 138/173 processed.
# API Batch 139/173 processed.
# API Batch 140/173 processed.
# API Batch 141/173 processed.
# API Batch 142/173 processed.
# API Batch 143/173 processed.
# API Batch 144/173 processed.
# API Batch 145/173 processed.
# API Batch 146/173 processed.
# API Batch 147/173 processed.
# API Batch 148/173 processed.
# API Batch 149/173 processed.
# API Batch 150/173 processed.
# API Batch 151/173 processed.
# API Batch 152/173 processed.
# API Batch 153/173 processed.
# API Batch 154/173 processed.
# API Batch 155/173 processed.
# API Batch 156/173 processed.
# API Batch 157/173 processed.
# API Batch 158/173 processed.
# API Batch 159/173 processed.
# API Batch 160/173 processed.
# API Batch 161/173 processed.
# API Batch 162/173 processed.
# API Batch 163/173 processed.
# API Batch 164/173 processed.
# API Batch 165/173 processed.
# API Batch 166/173 processed.
# API Batch 167/173 processed.
# API Batch 168/173 processed.
# API Batch 169/173 processed.
# API Batch 170/173 processed.
# API Batch 171/173 processed.
# API Batch 172/173 processed.
# API Batch 173/173 processed.
# Big Query Rows 8650 processed into extract_layer.api_sportdevs_fb_lineups.

# %%
# LOAD line ups extract data into BIQ QUERY load_layer table

# Set the target load dataset and table names
load_dataset_name = 'load_layer'
load_table_name = 'all_api_sportdevs_fb_lineups'
table_ref = client.dataset(load_dataset_name).table(load_table_name)


# Delete rows already inserted
delete_query = f"DELETE FROM `{load_dataset_name}.{load_table_name}` WHERE id IN (SELECT DISTINCT id FROM `{dataset_name}.{table_name}`)"
delete_job = client.query(delete_query)
delete_result = delete_job.result()
total_rows_deleted = delete_result.num_dml_affected_rows

if total_rows_deleted == 0:
    print(f"No rows were deleted from {load_dataset_name}.{load_table_name}.")
else:
   print(f"Total rows deleted from {load_dataset_name}.{load_table_name}: {total_rows_deleted}")

# Define the load job configuration
job_config = bigquery.QueryJobConfig(
    destination=table_ref,
    write_disposition=bigquery.WriteDisposition.WRITE_APPEND,
    schema_update_options=[
        bigquery.SchemaUpdateOption.ALLOW_FIELD_ADDITION
    ]
)

# Define the SQL query
insert_query = f"SELECT * FROM `{dataset_name}.{table_name}`"

# Run the load job and wait for the job to complete
load_job = client.query(insert_query, job_config=job_config)

# Wait for the job to complete
job.result()
total_rows = job.output_rows

print(f"Big Query Rows {total_rows} processed into {load_dataset_name}.{load_table_name}")
# Out:
# Total rows deleted from load_layer.all_api_sportdevs_fb_lineups: 7546
# Big Query Rows 8650 processed into load_layer.all_api_sportdevs_fb_lineups
